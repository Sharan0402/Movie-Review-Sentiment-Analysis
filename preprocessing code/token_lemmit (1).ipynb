# %% [markdown]
# 1. Stopwords are common words that are often removed during the preprocessing of natural language text data.Examples of stopwords in English include "the," "and," "is," "of," "in," etc.
#
# 2. Tokenization is the process of breaking down a sequence of text into individual units, known as tokens.
# Word Tokenization:["Tokenization", "is", "important", "for", "NLP"]
# Sentence Tokenization:["This is sentence one.", "This is sentence two."]
# **NLTK (Natural Language Toolkit) and spaCy in Python are commonly used for tokenization.**
#
# 3. Lemmatization: Lemmatization is a linguistic and natural language processing (NLP) technique that involves reducing words to their base or root form.\
# Example:\
#  Word: "Better"\
# Stemming Result: "Better" (No change)\
# Lemmatization Result: "Good"

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import re
from nltk.stem import WordNetLemmatizer
import nltk
import ssl
from nltk.corpus import wordnet as wn
from nltk.corpus import sentiwordnet as swn

# %%
path="/content/drive/MyDrive/ML_project_datasheets/Final_code/preprocessed_data.csv"
data= pd.read_csv(path)

# %%
data.head()
# Out:
#                                           reviewText  \
# 0  really happy they got evangelised .. spoiler a...
# 1  Having lived in West New Guinea (Papua) during...
# 2  Excellent look into contextualizing the Gospel...
# 3  More than anything, I've been challenged to fi...
# 4  This is a great movie for a missionary going i...
#
#                             Review_without_stopwords
# 0  really happy they got evangelised spoiler aler...
# 1  having lived in west new guinea papua during t...
# 2  excellent look into contextualizing the gospel...
# 3  more than anything  ve been challenged to find...
# 4  this is  great movie for  missionary going int...

# %%
nltk.download('stopwords')
nltk.download('punkt')
# Function to tokenize and remove the stopwords
def rem_stopwords_tokenize(data, name):
    def getting(sen):
        example_sent = str(sen)  # Convert to string to handle non-string inputs
        stop_words = set(stopwords.words('english'))
        word_tokens = word_tokenize(example_sent)
        filtered_sentence = [w for w in word_tokens if not w in stop_words]
        return filtered_sentence

    # Using "getting(sen)" function to append edited sentence to data
    x = []
    for i in data[name].values:
        x.append(getting(i))
    data[name] = x
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
# Using tokenizer and removing the stopwords
rem_stopwords_tokenize(data,'Review_without_stopwords')

# %%
data.head()
# Out:
#                                           reviewText  \
# 0  really happy they got evangelised .. spoiler a...
# 1  Having lived in West New Guinea (Papua) during...
# 2  Excellent look into contextualizing the Gospel...
# 3  More than anything, I've been challenged to fi...
# 4  This is a great movie for a missionary going i...
#
#                             Review_without_stopwords
# 0  [really, happy, got, evangelised, spoiler, ale...
# 1  [lived, west, new, guinea, papua, time, period...
# 2  [excellent, look, contextualizing, gospel, god...
# 3  [anything, challenged, find, ways, share, chri...
# 4  [great, movie, missionary, going, foreign, cou...

# %%
# Converting all the texts back to sentences
def make_sentences(data,name):
    data[name]=data[name].apply(lambda x: ' '.join([i for i in x]))

make_sentences(data,'Review_without_stopwords')

# %%
data.head()
# Out:
#                                           reviewText  \
# 0  really happy they got evangelised .. spoiler a...
# 1  Having lived in West New Guinea (Papua) during...
# 2  Excellent look into contextualizing the Gospel...
# 3  More than anything, I've been challenged to fi...
# 4  This is a great movie for a missionary going i...
#
#                             Review_without_stopwords
# 0  really happy got evangelised spoiler alert hap...
# 1  lived west new guinea papua time period covere...
# 2  excellent look contextualizing gospel god sove...
# 3  anything challenged find ways share christ cul...
# 4  great movie missionary going foreign country e...

# %%
#copy ata['Review_without_stopwords'] column in final_Edit
final_Edit = data['Review_without_stopwords'].copy()

# %%
#add "After_lemmatization" column in data and assign final_Edit values to it
data["After_lemmatization"] = final_Edit

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
# Lemmatization Function
data['After_lemmatization'].dropna(inplace=True)
lemmatizer = WordNetLemmatizer()
def Lemmatization(data,name):
    def getting2(sen):

        example = sen
        output_sentence =[]
        word_tokens2 = word_tokenize(example)
        lemmatized_output = [lemmatizer.lemmatize(w) for w in word_tokens2]

        # Remove characters which have length less than 2
        without_single_chr = [word for word in lemmatized_output if len(word) >= 2]
        # Remove numbers
        cleaned_data_title = [word for word in without_single_chr if not word.isnumeric()]

        return cleaned_data_title
# Using "getting2(sen)" function to append edited sentence to data
    x=[]
    for i in data[name].values:
        x.append(getting2(i))
    data[name]=x
# Using the Lemmatization function to lemmatize the hotel data
Lemmatization(data,'After_lemmatization')

# %%
data.head()
# Out:
#                                           reviewText  \
# 0  really happy they got evangelised .. spoiler a...
# 1  Having lived in West New Guinea (Papua) during...
# 2  Excellent look into contextualizing the Gospel...
# 3  More than anything, I've been challenged to fi...
# 4  This is a great movie for a missionary going i...
#
#                             Review_without_stopwords  \
# 0  really happy got evangelised spoiler alert hap...
# 1  lived west new guinea papua time period covere...
# 2  excellent look contextualizing gospel god sove...
# 3  anything challenged find ways share christ cul...
# 4  great movie missionary going foreign country e...
#
#                                  After_lemmatization
# 0  [really, happy, got, evangelised, spoiler, ale...
# 1  [lived, west, new, guinea, papua, time, period...
# 2  [excellent, look, contextualizing, gospel, god...
# 3  [anything, challenged, find, way, share, chris...
# 4  [great, movie, missionary, going, foreign, cou...

# %%
# Converting all the texts back to sentences
make_sentences(data,'After_lemmatization')

# %%
data.head()
# Out:
#                                           reviewText  \
# 0  really happy they got evangelised .. spoiler a...
# 1  Having lived in West New Guinea (Papua) during...
# 2  Excellent look into contextualizing the Gospel...
# 3  More than anything, I've been challenged to fi...
# 4  This is a great movie for a missionary going i...
#
#                             Review_without_stopwords  \
# 0  really happy got evangelised spoiler alert hap...
# 1  lived west new guinea papua time period covere...
# 2  excellent look contextualizing gospel god sove...
# 3  anything challenged find ways share christ cul...
# 4  great movie missionary going foreign country e...
#
#                                  After_lemmatization
# 0  really happy got evangelised spoiler alert hap...
# 1  lived west new guinea papua time period covere...
# 2  excellent look contextualizing gospel god sove...
# 3  anything challenged find way share christ cult...
# 4  great movie missionary going foreign country e...

# %%
import nltk
nltk.download('averaged_perceptron_tagger')

# %%
data.to_csv("/content/drive/MyDrive/ML_project_datasheets/Final_code/After_tokeni_lemmati_data.csv")
